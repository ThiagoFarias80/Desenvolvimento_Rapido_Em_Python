# %% [markdown]
# <a href="https://colab.research.google.com/github/ThiagoFarias80/Desenvolvimento_Rapido_Em_Python/blob/main/Dev_Rap_py3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd

# %%
dict_test = {
    "Nome": ["Jõao", 'Maria', 'José', 'Silvio',"Patricia",'Leonides', 'Kayo', 'Morgana', 'Flavio', 'Elisson', 'Helena'],
    "Gênero" :["Masculino", 'Feminino', 'Masculino', 'Masculino', 'Feminino', 'Mas', 'Masc', 'fem', 'masc', 'Homem', 'Mulher'],
    "Idade": [52, 47, 65, 34, 20, 26, 38, 24, 31, 22, 18],
    "UF": ['PE', 'PE', "PB", 'RN', 'PB', 'PE','PE', 'PE', 'PE', 'PE', 'SP']
}

df = pd.DataFrame(dict_test)
df.head ()
# Out:
#        Nome     Gênero  Idade  UF
# 0      Jõao  Masculino     52  PE
# 1     Maria   Feminino     47  PE
# 2      José  Masculino     65  PB
# 3    Silvio  Masculino     34  RN
# 4  Patricia   Feminino     20  PB

# %%
#Filtrando as linhas referentes a PE
df = df[df['UF'] == 'PE']
df.head()
# Out:
#        Nome     Gênero  Idade  UF
# 0      Jõao  Masculino     52  PE
# 1     Maria   Feminino     47  PE
# 5  Leonides        Mas     26  PE
# 6      Kayo       Masc     38  PE
# 7   Morgana        fem     24  PE

# %%
#Não usando nenhum metodo
df = df[['Gênero', 'Nome']]
df.head()
# Out:
#       Gênero      Nome
# 0  Masculino      Jõao
# 1   Feminino     Maria
# 5        Mas  Leonides
# 6       Masc      Kayo
# 7        fem   Morgana

# %%
#Usando o metodo 'Drop'
df = df.drop(labels=['UF'], axis=1)
#axis = 1 é a coluna e axis=0 é a linha
df.head()
# Out:
#        Nome     Gênero  Idade
# 0      Jõao  Masculino     52
# 1     Maria   Feminino     47
# 2      José  Masculino     65
# 3    Silvio  Masculino     34
# 4  Patricia   Feminino     20
