# %% [markdown]
# <a href="https://colab.research.google.com/github/ThiagoFarias80/Desenvolvimento_Rapido_Em_Python/blob/main/devrappy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
#importando a biblioteca dos pandas
import pandas as pd

# %%
grupos = ['Produto A', 'produto B', 'Produto C']
valores = [1, 10, 100]

# %%
grupos
# Out:
# ['Produto A', 'produto B', 'Produto C']

# %%
valores
# Out:
# [1, 10, 100]

# %%
#Criando um dicionario de dados
dict_test = {
    "Nome": ["Jõao", 'Maria', 'José', 'Silvio',"Patricia",'Leonides', 'Kayo', 'Morgana', 'Flavio', 'Elisson', 'Helena'],
    "Gênero" :["Masculino", 'Feminino', 'Masculino', 'Masculino', 'Feminino', 'Mas', 'Masc', 'fem', 'masc', 'Homem', 'Mulher'],
    "Idade": [52, 47, 65, 34, 20, 26, 38, 24, 31, 22, 18],
    "UF": ['PE', 'PE', "PB", 'RN', 'PB', 'PE','PE', 'PE', 'PE', 'PE', 'SP']
}

# %%
# Criando data frame
df = pd.DataFrame(dict_test)

# %%
# Metodo head() imprime as 5 linhas inicias do dataframe.
df.head ()
# Out:
#        Nome     Gênero  Idade  UF
# 0      Jõao  Masculino     52  PE
# 1     Maria   Feminino     47  PE
# 2      José  Masculino     65  PB
# 3    Silvio  Masculino     34  RN
# 4  Patricia   Feminino     20  PB

# %%
# Imprimindo a 10 primeiras linhas do dataframe.
df.head(10)
# Out:
#        Nome     Gênero  Idade  UF
# 0      Jõao  Masculino     52  PE
# 1     Maria   Feminino     47  PE
# 2      José  Masculino     65  PB
# 3    Silvio  Masculino     34  RN
# 4  Patricia   Feminino     20  PB
# 5  Leonides        Mas     26  PE
# 6      Kayo       Masc     38  PE
# 7   Morgana        fem     24  PE
# 8    Flavio       masc     31  PE
# 9   Elisson      Homem     22  PE
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Idade'], **{})
# chart
# ...

# %%
# Metodo tail() Imprime as 5 ultimas linhas.
df.tail()
# Out:
#        Nome  Gênero  Idade  UF
# 6      Kayo    Masc     38  PE
# 7   Morgana     fem     24  PE
# 8    Flavio    masc     31  PE
# 9   Elisson   Homem     22  PE
# 10   Helena  Mulher     18  SP

# %%
# Imprime as 15 ultimas linhas.
df.tail(15)
# Out:
#         Nome     Gênero  Idade  UF
# 0       Jõao  Masculino     52  PE
# 1      Maria   Feminino     47  PE
# 2       José  Masculino     65  PB
# 3     Silvio  Masculino     34  RN
# 4   Patricia   Feminino     20  PB
# 5   Leonides        Mas     26  PE
# 6       Kayo       Masc     38  PE
# 7    Morgana        fem     24  PE
# 8     Flavio       masc     31  PE
# 9    Elisson      Homem     22  PE
# 10    Helena     Mulher     18  SP

# %%
# Métodos describe() Exibe informações estatísticas das coluna NUMERICAS da base de dados.

# Várias informações como desvio padrão, média, valor mínimo e valor máximos de colunas.

df.describe()
# Out:
#            Idade
# count  11.000000
# mean   34.272727
# std    14.960554
# min    18.000000
# 25%    23.000000
# 50%    31.000000
# 75%    42.500000
# max    65.000000

# %%
# Atributos columns retorna o nome das colunas do dataframe
df.columns
# Out:
# Index(['Nome', 'Gênero', 'Idade', 'UF'], dtype='object')

# %%
# Métodos count() retorna a quantidade de linhas de todas as colunas.
df.count()
# Out:
# Nome      11
# Gênero    11
# Idade     11
# UF        11
# dtype: int64

# %%
# Imprime Informações Sobre Colunas e uso de memória
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    11 non-null     object
#  1   Gênero  11 non-null     object
#  2   Idade   11 non-null     int64
#  3   UF      11 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 480.0+ bytes

# %%
#Retorna em formato de tupla a quantidade de linhas e colunas do dataset.
df.shape
# Out:
# (11, 4)

# %%
# Metodo sample() Imprime uma amostra aleatória do dataset.
df.sample(11)
# Out:
#         Nome     Gênero  Idade  UF
# 1      Maria   Feminino     47  PE
# 10    Helena     Mulher     18  SP
# 8     Flavio       masc     31  PE
# 0       Jõao  Masculino     52  PE
# 7    Morgana        fem     24  PE
# 3     Silvio  Masculino     34  RN
# 9    Elisson      Homem     22  PE
# 2       José  Masculino     65  PB
# 6       Kayo       Masc     38  PE
# 4   Patricia   Feminino     20  PB
# 5   Leonides        Mas     26  PE
